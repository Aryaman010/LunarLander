# %%
import gym
import numpy as np
from stable_baselines3 import DDPG

from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
#from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

# %%
env_name = 'LunarLander-v2'
env = gym.make(env_name)

# %%
from stable_baselines.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise, AdaptiveParamNoiseSpec



n_actions = env.action_space.shape[0]
param_noise = None
action_noise = OrnsteinUhlenbeckActionNoise(mean=np.zeros(n_actions), sigma=float(0.5) * np.ones(n_actions))

model = DDPG("MlpPolicy", env, verbose=1, param_noise=param_noise, action_noise=action_noise)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-79-df4a548ea645> in <module>
#       3
#       4
# ----> 5 n_actions = env.action_space.shape[0]
#       6 param_noise = None
#       7 action_noise = OrnsteinUhlenbeckActionNoise(mean=np.zeros(n_actions), sigma=float(0.5) * np.ones(n_actions))
#
# IndexError: tuple index out of range

# %%
env = gym.make(env_name)
env = DummyVecEnv([lambda: env])
model = DQN("MlpPolicy", env, verbose=2)

# %%
model.learn(total_timesteps=50000)
# Out:
# --------------------------------------
# | approxkl           | 0.006785115   |
# | clipfrac           | 0.107421875   |
# | explained_variance | 5.25e-06      |
# | fps                | 260           |
# | n_updates          | 1             |
# | policy_entropy     | 0.76274455    |
# | policy_loss        | -0.0091859745 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 21.946287     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0058295834 |
# | clipfrac           | 0.0859375    |
# | explained_variance | -5.13e-06    |
# | fps                | 468          |
# | n_updates          | 2            |
# | policy_entropy     | 0.86609465   |
# | policy_loss        | -0.003038602 |
# | serial_timesteps   | 256          |
# | time_elapsed       | 0.492        |
# | total_timesteps    | 256          |
# | value_loss         | 2.6122632    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00097041513 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.15e-06     |
# | fps                | 406           |
# | n_updates          | 3             |
# | policy_entropy     | 0.8809694     |
# | policy_loss        | 0.0016394249  |
# | serial_timesteps   | 384           |
# | time_elapsed       | 0.766         |
# | total_timesteps    | 384           |
# | value_loss         | 3.3461661     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0036079115 |
# | clipfrac           | 0.046875     |
# | explained_variance | -9.54e-07    |
# | fps                | 316          |
# | n_updates          | 4            |
# | policy_entropy     | 0.79766995   |
# | policy_loss        | -0.002890141 |
# | serial_timesteps   | 512          |
# | time_elapsed       | 1.08         |
# | total_timesteps    | 512          |
# | value_loss         | 4.004078     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0070485882 |
# | clipfrac           | 0.123046875  |
# | explained_variance | 0            |
# | fps                | 319          |
# | n_updates          | 5            |
# | policy_entropy     | 0.881926     |
# | policy_loss        | -0.005158275 |
# | serial_timesteps   | 640          |
# | time_elapsed       | 1.49         |
# | total_timesteps    | 640          |
# | value_loss         | 4.767681     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00041622907 |
# | clipfrac           | 0.0           |
# | explained_variance | 3.99e-06      |
# | fps                | 290           |
# | n_updates          | 6             |
# | policy_entropy     | 0.88173294    |
# | policy_loss        | 0.001803159   |
# | serial_timesteps   | 768           |
# | time_elapsed       | 1.89          |
# | total_timesteps    | 768           |
# | value_loss         | 2.7501013     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0040628314  |
# | clipfrac           | 0.0625        |
# | explained_variance | -1.55e-06     |
# | fps                | 258           |
# | n_updates          | 7             |
# | policy_entropy     | 0.8114825     |
# | policy_loss        | -0.0094417315 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 2.33          |
# | total_timesteps    | 896           |
# | value_loss         | 3.6091409     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0037656354 |
# | clipfrac           | 0.048828125  |
# | explained_variance | -6.79e-06    |
# | fps                | 272          |
# | n_updates          | 8            |
# | policy_entropy     | 0.78629243   |
# | policy_loss        | -0.008838844 |
# | serial_timesteps   | 1024         |
# | time_elapsed       | 2.83         |
# | total_timesteps    | 1024         |
# | value_loss         | 13.191418    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.00015792967  |
# | clipfrac           | 0.0            |
# | explained_variance | 3.16e-06       |
# | fps                | 533            |
# | n_updates          | 9              |
# | policy_entropy     | 0.853048       |
# | policy_loss        | -0.00034441485 |
# | serial_timesteps   | 1152           |
# | time_elapsed       | 3.3            |
# | total_timesteps    | 1152           |
# | value_loss         | 10.434341      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0052599907 |
# | clipfrac           | 0.07421875   |
# | explained_variance | -4.05e-06    |
# | fps                | 520          |
# | n_updates          | 10           |
# | policy_entropy     | 0.8459719    |
# | policy_loss        | -0.003722604 |
# | serial_timesteps   | 1280         |
# | time_elapsed       | 3.54         |
# | total_timesteps    | 1280         |
# | value_loss         | 4.093996     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.008358588  |
# | clipfrac           | 0.14453125   |
# | explained_variance | -7.27e-06    |
# | fps                | 422          |
# | n_updates          | 11           |
# | policy_entropy     | 0.9404309    |
# | policy_loss        | -0.012609917 |
# | serial_timesteps   | 1408         |
# | time_elapsed       | 3.79         |
# | total_timesteps    | 1408         |
# | value_loss         | 5.5967126    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.009431406  |
# | clipfrac           | 0.15234375   |
# | explained_variance | -8.58e-06    |
# | fps                | 531          |
# | n_updates          | 12           |
# | policy_entropy     | 0.8041407    |
# | policy_loss        | -0.009428882 |
# | serial_timesteps   | 1536         |
# | time_elapsed       | 4.09         |
# | total_timesteps    | 1536         |
# | value_loss         | 2.3559816    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.007640563  |
# | clipfrac           | 0.119140625  |
# | explained_variance | -1.31e-06    |
# | fps                | 509          |
# | n_updates          | 13           |
# | policy_entropy     | 0.80049044   |
# | policy_loss        | 0.0023816666 |
# | serial_timesteps   | 1664         |
# | time_elapsed       | 4.34         |
# | total_timesteps    | 1664         |
# | value_loss         | 2.4828568    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.010364442  |
# | clipfrac           | 0.11328125   |
# | explained_variance | -7.75e-06    |
# | fps                | 481          |
# | n_updates          | 14           |
# | policy_entropy     | 0.8577651    |
# | policy_loss        | -0.011454594 |
# | serial_timesteps   | 1792         |
# | time_elapsed       | 4.59         |
# | total_timesteps    | 1792         |
# | value_loss         | 2.16464      |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.004924803  |
# | clipfrac           | 0.072265625  |
# | explained_variance | -2e-05       |
# | fps                | 430          |
# | n_updates          | 15           |
# | policy_entropy     | 0.7532015    |
# | policy_loss        | -0.012302345 |
# | serial_timesteps   | 1920         |
# | time_elapsed       | 4.85         |
# | total_timesteps    | 1920         |
# | value_loss         | 4.1143336    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0008370794  |
# | clipfrac           | 0.001953125   |
# | explained_variance | 1.79e-05      |
# | fps                | 338           |
# | n_updates          | 16            |
# | policy_entropy     | 0.91174835    |
# | policy_loss        | -0.0043365476 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 5.15          |
# | total_timesteps    | 2048          |
# | value_loss         | 20.746964     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0012529143  |
# | clipfrac           | 0.005859375   |
# | explained_variance | -1.31e-06     |
# | fps                | 820           |
# | n_updates          | 17            |
# | policy_entropy     | 0.78562397    |
# | policy_loss        | -0.0016902848 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 5.53          |
# | total_timesteps    | 2176          |
# | value_loss         | 11.271146     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0052399207  |
# | clipfrac           | 0.07421875    |
# | explained_variance | -1.11e-05     |
# | fps                | 666           |
# | n_updates          | 18            |
# | policy_entropy     | 0.81032205    |
# | policy_loss        | -0.0093356455 |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 5.69          |
# | total_timesteps    | 2304          |
# | value_loss         | 5.8993607     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0059859315 |
# | clipfrac           | 0.080078125  |
# | explained_variance | -1.84e-05    |
# | fps                | 483          |
# | n_updates          | 19           |
# | policy_entropy     | 0.87838244   |
# | policy_loss        | -0.005487018 |
# | serial_timesteps   | 2432         |
# | time_elapsed       | 5.88         |
# | total_timesteps    | 2432         |
# | value_loss         | 5.1701365    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.006730897   |
# | clipfrac           | 0.09765625    |
# | explained_variance | -1.29e-05     |
# | fps                | 418           |
# | n_updates          | 20            |
# | policy_entropy     | 0.9120381     |
# | policy_loss        | -0.0073317084 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 6.15          |
# | total_timesteps    | 2560          |
# | value_loss         | 3.4644308     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.01015333    |
# | clipfrac           | 0.171875      |
# | explained_variance | -4.21e-05     |
# | fps                | 391           |
# | n_updates          | 21            |
# | policy_entropy     | 0.74410546    |
# | policy_loss        | -0.0112296045 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 6.45          |
# | total_timesteps    | 2688          |
# | value_loss         | 2.2892277     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0065383064 |
# | clipfrac           | 0.08984375   |
# | explained_variance | -8e-05       |
# | fps                | 389          |
# | n_updates          | 22           |
# | policy_entropy     | 0.90858144   |
# | policy_loss        | -0.013335608 |
# | serial_timesteps   | 2816         |
# | time_elapsed       | 6.78         |
# | total_timesteps    | 2816         |
# | value_loss         | 2.3627043    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0017920518  |
# | clipfrac           | 0.0078125     |
# | explained_variance | -5.4e-05      |
# | fps                | 391           |
# | n_updates          | 23            |
# | policy_entropy     | 0.86858326    |
# | policy_loss        | -0.0010320859 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 7.11          |
# | total_timesteps    | 2944          |
# | value_loss         | 2.8161879     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020244718 |
# | clipfrac           | 0.0           |
# | explained_variance | 8.94e-07      |
# | fps                | 576           |
# | n_updates          | 24            |
# | policy_entropy     | 0.72311676    |
# | policy_loss        | 0.0012269975  |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 7.44          |
# | total_timesteps    | 3072          |
# | value_loss         | 16.517288     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0034834547  |
# | clipfrac           | 0.048828125   |
# | explained_variance | -1.19e-06     |
# | fps                | 703           |
# | n_updates          | 25            |
# | policy_entropy     | 0.9073614     |
# | policy_loss        | -0.0065621515 |
# | serial_timesteps   | 3200          |
# | time_elapsed       | 7.67          |
# | total_timesteps    | 3200          |
# | value_loss         | 5.990683      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.005254763  |
# | clipfrac           | 0.06640625   |
# | explained_variance | -5.36e-06    |
# | fps                | 503          |
# | n_updates          | 26           |
# | policy_entropy     | 0.86706454   |
# | policy_loss        | -0.009302032 |
# | serial_timesteps   | 3328         |
# | time_elapsed       | 7.85         |
# | total_timesteps    | 3328         |
# | value_loss         | 2.8746464    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.005083615  |
# | clipfrac           | 0.0625       |
# | explained_variance | -1.41e-05    |
# | fps                | 357          |
# | n_updates          | 27           |
# | policy_entropy     | 0.8772996    |
# | policy_loss        | -0.006258852 |
# | serial_timesteps   | 3456         |
# | time_elapsed       | 8.1          |
# | total_timesteps    | 3456         |
# | value_loss         | 2.2355468    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00048468303 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.98e-06     |
# | fps                | 296           |
# | n_updates          | 28            |
# | policy_entropy     | 0.86424243    |
# | policy_loss        | -0.001843002  |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 8.46          |
# | total_timesteps    | 3584          |
# | value_loss         | 5.081307      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00090773933 |
# | clipfrac           | 0.0           |
# | explained_variance | 5.9e-06       |
# | fps                | 268           |
# | n_updates          | 29            |
# | policy_entropy     | 0.9558739     |
# | policy_loss        | -0.0019518306 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 8.89          |
# | total_timesteps    | 3712          |
# | value_loss         | 4.090722      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0006072696 |
# | clipfrac           | 0.0          |
# | explained_variance | -7.63e-06    |
# | fps                | 242          |
# | n_updates          | 30           |
# | policy_entropy     | 0.9853788    |
# | policy_loss        | -0.002818673 |
# | serial_timesteps   | 3840         |
# | time_elapsed       | 9.37         |
# | total_timesteps    | 3840         |
# | value_loss         | 4.794856     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00025380592 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.16e-05     |
# | fps                | 209           |
# | n_updates          | 31            |
# | policy_entropy     | 0.8798751     |
# | policy_loss        | 0.0013154362  |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 9.9           |
# | total_timesteps    | 3968          |
# | value_loss         | 4.012404      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010306716 |
# | clipfrac           | 0.0          |
# | explained_variance | -5.5e-05     |
# | fps                | 479          |
# | n_updates          | 32           |
# | policy_entropy     | 0.7451781    |
# | policy_loss        | 0.000373099  |
# | serial_timesteps   | 4096         |
# | time_elapsed       | 10.5         |
# | total_timesteps    | 4096         |
# | value_loss         | 17.427477    |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.010108445 |
# | clipfrac           | 0.14648438  |
# | explained_variance | -6.56e-06   |
# | fps                | 753         |
# | n_updates          | 33          |
# | policy_entropy     | 0.92457265  |
# | policy_loss        | -0.01597315 |
# | serial_timesteps   | 4224        |
# | time_elapsed       | 10.8        |
# | total_timesteps    | 4224        |
# | value_loss         | 4.6331735   |
# ------------------------------------
# --------------------------------------
# | approxkl           | 0.0014806986  |
# | clipfrac           | 0.0078125     |
# | explained_variance | -1.91e-05     |
# | fps                | 584           |
# | n_updates          | 34            |
# | policy_entropy     | 0.8837148     |
# | policy_loss        | -0.0022424012 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 11            |
# | total_timesteps    | 4352          |
# | value_loss         | 1.5701824     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0012959559  |
# | clipfrac           | 0.0           |
# | explained_variance | -1.45e-05     |
# | fps                | 496           |
# | n_updates          | 35            |
# | policy_entropy     | 0.88197356    |
# | policy_loss        | -0.0010390485 |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 11.2          |
# | total_timesteps    | 4480          |
# | value_loss         | 2.134354      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017766575  |
# | clipfrac           | 0.017578125   |
# | explained_variance | -5.69e-05     |
# | fps                | 463           |
# | n_updates          | 36            |
# | policy_entropy     | 0.82830566    |
# | policy_loss        | -0.0030632098 |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 11.4          |
# | total_timesteps    | 4608          |
# | value_loss         | 1.7907865     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0050904616  |
# | clipfrac           | 0.064453125   |
# | explained_variance | -5.92e-05     |
# | fps                | 410           |
# | n_updates          | 37            |
# | policy_entropy     | 0.8150383     |
# | policy_loss        | -0.0068802806 |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 11.7          |
# | total_timesteps    | 4736          |
# | value_loss         | 1.59372       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0055399993  |
# | clipfrac           | 0.078125      |
# | explained_variance | -3.95e-05     |
# | fps                | 392           |
# | n_updates          | 38            |
# | policy_entropy     | 0.82579       |
# | policy_loss        | -0.0053064697 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 12            |
# | total_timesteps    | 4864          |
# | value_loss         | 2.8778658     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010292965  |
# | clipfrac           | 0.009765625   |
# | explained_variance | -4.76e-05     |
# | fps                | 348           |
# | n_updates          | 39            |
# | policy_entropy     | 0.8983466     |
# | policy_loss        | -0.0011260656 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 12.4          |
# | total_timesteps    | 4992          |
# | value_loss         | 1.994308      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0013186308   |
# | clipfrac           | 0.009765625    |
# | explained_variance | -4.28e-05      |
# | fps                | 810            |
# | n_updates          | 40             |
# | policy_entropy     | 0.9039177      |
# | policy_loss        | -0.00051960524 |
# | serial_timesteps   | 5120           |
# | time_elapsed       | 12.7           |
# | total_timesteps    | 5120           |
# | value_loss         | 9.401227       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0017961895  |
# | clipfrac           | 0.015625      |
# | explained_variance | -5.6e-06      |
# | fps                | 699           |
# | n_updates          | 41            |
# | policy_entropy     | 0.87512255    |
# | policy_loss        | -0.0034750607 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 12.9          |
# | total_timesteps    | 5248          |
# | value_loss         | 1.5246276     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0016504272   |
# | clipfrac           | 0.00390625     |
# | explained_variance | -7.99e-06      |
# | fps                | 512            |
# | n_updates          | 42             |
# | policy_entropy     | 0.8979111      |
# | policy_loss        | -3.0542607e-05 |
# | serial_timesteps   | 5376           |
# | time_elapsed       | 13.1           |
# | total_timesteps    | 5376           |
# | value_loss         | 1.9271424      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0065638637 |
# | clipfrac           | 0.08984375   |
# | explained_variance | -4.29e-06    |
# | fps                | 406          |
# | n_updates          | 43           |
# | policy_entropy     | 0.9102652    |
# | policy_loss        | -0.015508822 |
# | serial_timesteps   | 5504         |
# | time_elapsed       | 13.3         |
# | total_timesteps    | 5504         |
# | value_loss         | 6.0068455    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00509351    |
# | clipfrac           | 0.05859375    |
# | explained_variance | -2.11e-05     |
# | fps                | 354           |
# | n_updates          | 44            |
# | policy_entropy     | 0.83558756    |
# | policy_loss        | -0.0047926786 |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 13.6          |
# | total_timesteps    | 5632          |
# | value_loss         | 1.8021295     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004249896   |
# | clipfrac           | 0.05859375    |
# | explained_variance | -4.34e-05     |
# | fps                | 330           |
# | n_updates          | 45            |
# | policy_entropy     | 0.90116507    |
# | policy_loss        | -0.0021495128 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 14            |
# | total_timesteps    | 5760          |
# | value_loss         | 1.5914211     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002345169   |
# | clipfrac           | 0.015625      |
# | explained_variance | -2.56e-05     |
# | fps                | 304           |
# | n_updates          | 46            |
# | policy_entropy     | 0.81649494    |
# | policy_loss        | -0.0017074803 |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 14.4          |
# | total_timesteps    | 5888          |
# | value_loss         | 3.6285763     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014295014 |
# | clipfrac           | 0.0           |
# | explained_variance | 3.75e-05      |
# | fps                | 310           |
# | n_updates          | 47            |
# | policy_entropy     | 0.76926214    |
# | policy_loss        | 0.0009961191  |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 14.8          |
# | total_timesteps    | 6016          |
# | value_loss         | 11.600881     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000698827   |
# | clipfrac           | 0.0           |
# | explained_variance | 5.96e-08      |
# | fps                | 842           |
# | n_updates          | 48            |
# | policy_entropy     | 0.6478159     |
# | policy_loss        | -0.0020014558 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 15.2          |
# | total_timesteps    | 6144          |
# | value_loss         | 82.97182      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.005089621   |
# | clipfrac           | 0.078125      |
# | explained_variance | -5.01e-06     |
# | fps                | 659           |
# | n_updates          | 49            |
# | policy_entropy     | 0.9158403     |
# | policy_loss        | -0.0014496953 |
# | serial_timesteps   | 6272          |
# | time_elapsed       | 15.4          |
# | total_timesteps    | 6272          |
# | value_loss         | 2.2801888     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.009770918  |
# | clipfrac           | 0.115234375  |
# | explained_variance | -3.81e-06    |
# | fps                | 531          |
# | n_updates          | 50           |
# | policy_entropy     | 0.77953297   |
# | policy_loss        | -0.013394659 |
# | serial_timesteps   | 6400         |
# | time_elapsed       | 15.6         |
# | total_timesteps    | 6400         |
# | value_loss         | 3.4678948    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0066795372 |
# | clipfrac           | 0.109375     |
# | explained_variance | -1.19e-07    |
# | fps                | 496          |
# | n_updates          | 51           |
# | policy_entropy     | 0.69535846   |
# | policy_loss        | -0.014914349 |
# | serial_timesteps   | 6528         |
# | time_elapsed       | 15.8         |
# | total_timesteps    | 6528         |
# | value_loss         | 5.2048283    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0015087813 |
# | clipfrac           | 0.0          |
# | explained_variance | -1.05e-05    |
# | fps                | 442          |
# | n_updates          | 52           |
# | policy_entropy     | 0.84556216   |
# | policy_loss        | 0.0010477221 |
# | serial_timesteps   | 6656         |
# | time_elapsed       | 16.1         |
# | total_timesteps    | 6656         |
# | value_loss         | 1.6235876    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0077435593 |
# | clipfrac           | 0.123046875  |
# | explained_variance | -1.5e-05     |
# | fps                | 425          |
# | n_updates          | 53           |
# | policy_entropy     | 0.7911164    |
# | policy_loss        | -0.012776083 |
# | serial_timesteps   | 6784         |
# | time_elapsed       | 16.4         |
# | total_timesteps    | 6784         |
# | value_loss         | 1.5233402    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0020616627  |
# | clipfrac           | 0.0234375     |
# | explained_variance | 2.26e-06      |
# | fps                | 397           |
# | n_updates          | 54            |
# | policy_entropy     | 0.7719272     |
# | policy_loss        | -0.0025840362 |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 16.7          |
# | total_timesteps    | 6912          |
# | value_loss         | 4.268832      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000478591   |
# | clipfrac           | 0.0           |
# | explained_variance | 3.44e-05      |
# | fps                | 457           |
# | n_updates          | 55            |
# | policy_entropy     | 0.657688      |
# | policy_loss        | 0.00034348015 |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 17            |
# | total_timesteps    | 7040          |
# | value_loss         | 28.128977     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019718052 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.79e-06     |
# | fps                | 790           |
# | n_updates          | 56            |
# | policy_entropy     | 0.81229097    |
# | policy_loss        | -0.0011515489 |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 17.3          |
# | total_timesteps    | 7168          |
# | value_loss         | 25.588654     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002876745   |
# | clipfrac           | 0.033203125   |
# | explained_variance | -1.47e-05     |
# | fps                | 618           |
# | n_updates          | 57            |
# | policy_entropy     | 0.93796396    |
# | policy_loss        | -0.0023757564 |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 17.4          |
# | total_timesteps    | 7296          |
# | value_loss         | 3.6222715     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0008225701 |
# | clipfrac           | 0.0          |
# | explained_variance | -8.7e-06     |
# | fps                | 518          |
# | n_updates          | 58           |
# | policy_entropy     | 0.78710306   |
# | policy_loss        | 0.0007924936 |
# | serial_timesteps   | 7424         |
# | time_elapsed       | 17.6         |
# | total_timesteps    | 7424         |
# | value_loss         | 4.112337     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0058965613 |
# | clipfrac           | 0.08984375   |
# | explained_variance | 1.71e-05     |
# | fps                | 516          |
# | n_updates          | 59           |
# | policy_entropy     | 0.82348883   |
# | policy_loss        | -0.008489263 |
# | serial_timesteps   | 7552         |
# | time_elapsed       | 17.9         |
# | total_timesteps    | 7552         |
# | value_loss         | 3.2944553    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0024170454 |
# | clipfrac           | 0.029296875  |
# | explained_variance | -2.6e-05     |
# | fps                | 483          |
# | n_updates          | 60           |
# | policy_entropy     | 0.8862852    |
# | policy_loss        | -0.003264385 |
# | serial_timesteps   | 7680         |
# | time_elapsed       | 18.1         |
# | total_timesteps    | 7680         |
# | value_loss         | 3.224819     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.008115495  |
# | clipfrac           | 0.123046875  |
# | explained_variance | -6.07e-05    |
# | fps                | 452          |
# | n_updates          | 61           |
# | policy_entropy     | 0.89601696   |
# | policy_loss        | -0.013153526 |
# | serial_timesteps   | 7808         |
# | time_elapsed       | 18.4         |
# | total_timesteps    | 7808         |
# | value_loss         | 1.657752     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00040451577 |
# | clipfrac           | 0.00390625    |
# | explained_variance | -4.98e-05     |
# | fps                | 425           |
# | n_updates          | 62            |
# | policy_entropy     | 0.74714684    |
# | policy_loss        | 0.0002206614  |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 18.7          |
# | total_timesteps    | 7936          |
# | value_loss         | 1.6859559     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0057444647 |
# | clipfrac           | 0.080078125  |
# | explained_variance | -0.000155    |
# | fps                | 554          |
# | n_updates          | 63           |
# | policy_entropy     | 0.81257147   |
# | policy_loss        | -0.010130991 |
# | serial_timesteps   | 8064         |
# | time_elapsed       | 19           |
# | total_timesteps    | 8064         |
# | value_loss         | 13.951255    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0014610034  |
# | clipfrac           | 0.009765625   |
# | explained_variance | -1.35e-05     |
# | fps                | 761           |
# | n_updates          | 64            |
# | policy_entropy     | 0.7989434     |
# | policy_loss        | -0.0025347648 |
# | serial_timesteps   | 8192          |
# | time_elapsed       | 19.2          |
# | total_timesteps    | 8192          |
# | value_loss         | 2.9337869     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0033792597  |
# | clipfrac           | 0.0390625     |
# | explained_variance | -6.91e-06     |
# | fps                | 547           |
# | n_updates          | 65            |
# | policy_entropy     | 0.6863358     |
# | policy_loss        | -0.0020787832 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 19.4          |
# | total_timesteps    | 8320          |
# | value_loss         | 3.763709      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0027410262 |
# | clipfrac           | 0.0390625    |
# | explained_variance | -2.12e-05    |
# | fps                | 422          |
# | n_updates          | 66           |
# | policy_entropy     | 0.87402254   |
# | policy_loss        | -0.004064112 |
# | serial_timesteps   | 8448         |
# | time_elapsed       | 19.6         |
# | total_timesteps    | 8448         |
# | value_loss         | 3.5228832    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.005368515  |
# | clipfrac           | 0.076171875  |
# | explained_variance | -5.75e-05    |
# | fps                | 345          |
# | n_updates          | 67           |
# | policy_entropy     | 0.78346044   |
# | policy_loss        | -0.010052906 |
# | serial_timesteps   | 8576         |
# | time_elapsed       | 19.9         |
# | total_timesteps    | 8576         |
# | value_loss         | 2.3975792    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.003193014  |
# | clipfrac           | 0.0390625    |
# | explained_variance | -8.49e-05    |
# | fps                | 304          |
# | n_updates          | 68           |
# | policy_entropy     | 0.8716772    |
# | policy_loss        | -0.007642578 |
# | serial_timesteps   | 8704         |
# | time_elapsed       | 20.3         |
# | total_timesteps    | 8704         |
# | value_loss         | 1.4617583    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0008802275 |
# | clipfrac           | 0.0          |
# | explained_variance | -6.37e-05    |
# | fps                | 236          |
# | n_updates          | 69           |
# | policy_entropy     | 0.895335     |
# | policy_loss        | 0.0007060688 |
# | serial_timesteps   | 8832         |
# | time_elapsed       | 20.7         |
# | total_timesteps    | 8832         |
# | value_loss         | 6.5350103    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0016115529  |
# | clipfrac           | 0.015625      |
# | explained_variance | -5.51e-05     |
# | fps                | 193           |
# | n_updates          | 70            |
# | policy_entropy     | 0.82123464    |
# | policy_loss        | -0.0046955543 |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 21.3          |
# | total_timesteps    | 8960          |
# | value_loss         | 3.3018837     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001468313   |
# | clipfrac           | 0.005859375   |
# | explained_variance | -7.22e-05     |
# | fps                | 449           |
# | n_updates          | 71            |
# | policy_entropy     | 0.7751367     |
# | policy_loss        | -0.0028903084 |
# | serial_timesteps   | 9088          |
# | time_elapsed       | 21.9          |
# | total_timesteps    | 9088          |
# | value_loss         | 18.9094       |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00032953854  |
# | clipfrac           | 0.0            |
# | explained_variance | -1.19e-06      |
# | fps                | 723            |
# | n_updates          | 72             |
# | policy_entropy     | 0.820282       |
# | policy_loss        | -0.00065504975 |
# | serial_timesteps   | 9216           |
# | time_elapsed       | 22.2           |
# | total_timesteps    | 9216           |
# | value_loss         | 4.0128403      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0032912854  |
# | clipfrac           | 0.041015625   |
# | explained_variance | -2.15e-06     |
# | fps                | 592           |
# | n_updates          | 73            |
# | policy_entropy     | 0.9280103     |
# | policy_loss        | -0.0003977022 |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 22.4          |
# | total_timesteps    | 9344          |
# | value_loss         | 5.028161      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0077350484 |
# | clipfrac           | 0.107421875  |
# | explained_variance | -5.25e-06    |
# | fps                | 561          |
# | n_updates          | 74           |
# | policy_entropy     | 0.8556022    |
# | policy_loss        | -0.013374286 |
# | serial_timesteps   | 9472         |
# | time_elapsed       | 22.6         |
# | total_timesteps    | 9472         |
# | value_loss         | 4.7823076    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0031426915 |
# | clipfrac           | 0.04296875   |
# | explained_variance | -9.54e-07    |
# | fps                | 462          |
# | n_updates          | 75           |
# | policy_entropy     | 0.8180194    |
# | policy_loss        | -0.006082617 |
# | serial_timesteps   | 9600         |
# | time_elapsed       | 22.8         |
# | total_timesteps    | 9600         |
# | value_loss         | 2.124394     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0040702024  |
# | clipfrac           | 0.05859375    |
# | explained_variance | -1.57e-05     |
# | fps                | 403           |
# | n_updates          | 76            |
# | policy_entropy     | 0.80711263    |
# | policy_loss        | -0.0067485003 |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 23.1          |
# | total_timesteps    | 9728          |
# | value_loss         | 1.9245733     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0014000712  |
# | clipfrac           | 0.001953125   |
# | explained_variance | 3.36e-05      |
# | fps                | 345           |
# | n_updates          | 77            |
# | policy_entropy     | 0.8940525     |
# | policy_loss        | -0.0035087774 |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 23.4          |
# | total_timesteps    | 9856          |
# | value_loss         | 1.7542182     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0068973964 |
# | clipfrac           | 0.0859375    |
# | explained_variance | -9.45e-05    |
# | fps                | 318          |
# | n_updates          | 78           |
# | policy_entropy     | 0.79652905   |
# | policy_loss        | -0.010434108 |
# | serial_timesteps   | 9984         |
# | time_elapsed       | 23.8         |
# | total_timesteps    | 9984         |
# | value_loss         | 2.7633262    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0021737665 |
# | clipfrac           | 0.029296875  |
# | explained_variance | -0.000273    |
# | fps                | 695          |
# | n_updates          | 79           |
# | policy_entropy     | 0.77066904   |
# | policy_loss        | -0.004895283 |
# | serial_timesteps   | 10112        |
# | time_elapsed       | 24.2         |
# | total_timesteps    | 10112        |
# | value_loss         | 14.10349     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.004673683  |
# | clipfrac           | 0.056640625  |
# | explained_variance | -6.79e-06    |
# | fps                | 666          |
# | n_updates          | 80           |
# | policy_entropy     | 0.80089104   |
# | policy_loss        | -0.005178551 |
# | serial_timesteps   | 10240        |
# | time_elapsed       | 24.4         |
# | total_timesteps    | 10240        |
# | value_loss         | 2.5649822    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0026981109  |
# | clipfrac           | 0.037109375   |
# | explained_variance | -9.42e-06     |
# | fps                | 499           |
# | n_updates          | 81            |
# | policy_entropy     | 0.7710976     |
# | policy_loss        | -0.0053790407 |
# | serial_timesteps   | 10368         |
# | time_elapsed       | 24.6          |
# | total_timesteps    | 10368         |
# | value_loss         | 3.030076      |
# --------------------------------------
# ------------------------------------
# | approxkl           | 0.008340095 |
# | clipfrac           | 0.123046875 |
# | explained_variance | -2.03e-05   |
# | fps                | 398         |
# | n_updates          | 82          |
# | policy_entropy     | 0.90417564  |
# | policy_loss        | -0.01151222 |
# | serial_timesteps   | 10496       |
# | time_elapsed       | 24.8        |
# | total_timesteps    | 10496       |
# | value_loss         | 1.6139853   |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.0017221221 |
# | clipfrac           | 0.01953125   |
# | explained_variance | -3e-05       |
# | fps                | 322          |
# | n_updates          | 83           |
# | policy_entropy     | 0.814565     |
# | policy_loss        | -0.004179132 |
# | serial_timesteps   | 10624        |
# | time_elapsed       | 25.2         |
# | total_timesteps    | 10624        |
# | value_loss         | 1.9686131    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0015712833 |
# | clipfrac           | 0.015625     |
# | explained_variance | -1.66e-05    |
# | fps                | 247          |
# | n_updates          | 84           |
# | policy_entropy     | 0.7953589    |
# | policy_loss        | 0.0010960886 |
# | serial_timesteps   | 10752        |
# | time_elapsed       | 25.6         |
# | total_timesteps    | 10752        |
# | value_loss         | 5.872181     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0020876087 |
# | clipfrac           | 0.015625     |
# | explained_variance | 2.56e-06     |
# | fps                | 257          |
# | n_updates          | 85           |
# | policy_entropy     | 0.86255383   |
# | policy_loss        | -0.00937005  |
# | serial_timesteps   | 10880        |
# | time_elapsed       | 26.1         |
# | total_timesteps    | 10880        |
# | value_loss         | 8.076585     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00065810053 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.34e-05     |
# | fps                | 247           |
# | n_updates          | 86            |
# | policy_entropy     | 0.80250907    |
# | policy_loss        | 0.0021391695  |
# | serial_timesteps   | 11008         |
# | time_elapsed       | 26.6          |
# | total_timesteps    | 11008         |
# | value_loss         | 10.237917     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00025081134 |
# | clipfrac           | 0.0           |
# | explained_variance | 8.94e-07      |
# | fps                | 853           |
# | n_updates          | 87            |
# | policy_entropy     | 0.7631065     |
# | policy_loss        | -0.0004643149 |
# | serial_timesteps   | 11136         |
# | time_elapsed       | 27.1          |
# | total_timesteps    | 11136         |
# | value_loss         | 32.253036     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0054566693 |
# | clipfrac           | 0.0703125    |
# | explained_variance | -2.38e-07    |
# | fps                | 666          |
# | n_updates          | 88           |
# | policy_entropy     | 0.7565892    |
# | policy_loss        | -0.003977515 |
# | serial_timesteps   | 11264        |
# | time_elapsed       | 27.2         |
# | total_timesteps    | 11264        |
# | value_loss         | 2.125146     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0017565133 |
# | clipfrac           | 0.005859375  |
# | explained_variance | -2.03e-06    |
# | fps                | 574          |
# | n_updates          | 89           |
# | policy_entropy     | 0.8327197    |
# | policy_loss        | -0.00302826  |
# | serial_timesteps   | 11392        |
# | time_elapsed       | 27.4         |
# | total_timesteps    | 11392        |
# | value_loss         | 8.369305     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00047696862 |
# | clipfrac           | 0.0           |
# | explained_variance | 1.67e-06      |
# | fps                | 684           |
# | n_updates          | 90            |
# | policy_entropy     | 0.6139297     |
# | policy_loss        | -0.0015046867 |
# | serial_timesteps   | 11520         |
# | time_elapsed       | 27.7          |
# | total_timesteps    | 11520         |
# | value_loss         | 253.14465     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.519335e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 5.96e-07       |
# | fps                | 711            |
# | n_updates          | 91             |
# | policy_entropy     | 0.760684       |
# | policy_loss        | -0.00011391146 |
# | serial_timesteps   | 11648          |
# | time_elapsed       | 27.8           |
# | total_timesteps    | 11648          |
# | value_loss         | 9.640496       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0033145244  |
# | clipfrac           | 0.0390625     |
# | explained_variance | -3.58e-06     |
# | fps                | 579           |
# | n_updates          | 92            |
# | policy_entropy     | 0.64297706    |
# | policy_loss        | -0.0020853938 |
# | serial_timesteps   | 11776         |
# | time_elapsed       | 28            |
# | total_timesteps    | 11776         |
# | value_loss         | 5.5204315     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005041925  |
# | clipfrac           | 0.0           |
# | explained_variance | -6.08e-06     |
# | fps                | 345           |
# | n_updates          | 93            |
# | policy_entropy     | 0.8744622     |
# | policy_loss        | -0.0013624465 |
# | serial_timesteps   | 11904         |
# | time_elapsed       | 28.2          |
# | total_timesteps    | 11904         |
# | value_loss         | 4.449321      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.007523265  |
# | clipfrac           | 0.11328125   |
# | explained_variance | -6.44e-06    |
# | fps                | 364          |
# | n_updates          | 94           |
# | policy_entropy     | 0.76079905   |
# | policy_loss        | -0.009683223 |
# | serial_timesteps   | 12032        |
# | time_elapsed       | 28.6         |
# | total_timesteps    | 12032        |
# | value_loss         | 8.19345      |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0015712455  |
# | clipfrac           | 0.005859375   |
# | explained_variance | 2.21e-05      |
# | fps                | 341           |
# | n_updates          | 95            |
# | policy_entropy     | 0.78676504    |
# | policy_loss        | -0.0019005334 |
# | serial_timesteps   | 12160         |
# | time_elapsed       | 29            |
# | total_timesteps    | 12160         |
# | value_loss         | 3.7704515     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00045551854 |
# | clipfrac           | 0.0           |
# | explained_variance | 9.78e-06      |
# | fps                | 472           |
# | n_updates          | 96            |
# | policy_entropy     | 0.5753259     |
# | policy_loss        | -0.0030789003 |
# | serial_timesteps   | 12288         |
# ...
# | explained_variance | 8.94e-07     |
# | fps                | 346          |
# | n_updates          | 359          |
# | policy_entropy     | 0.6940322    |
# | policy_loss        | -0.005531749 |
# | serial_timesteps   | 45952        |
# | time_elapsed       | 132          |
# | total_timesteps    | 45952        |
# | value_loss         | 2.187981     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0018262404  |
# | clipfrac           | 0.009765625   |
# | explained_variance | 3.22e-06      |
# | fps                | 313           |
# | n_updates          | 360           |
# | policy_entropy     | 0.8555144     |
# | policy_loss        | -0.0022897704 |
# | serial_timesteps   | 46080         |
# | time_elapsed       | 132           |
# | total_timesteps    | 46080         |
# | value_loss         | 2.374444      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0008237315   |
# | clipfrac           | 0.0            |
# | explained_variance | 6.62e-06       |
# | fps                | 474            |
# | n_updates          | 361            |
# | policy_entropy     | 0.579064       |
# | policy_loss        | -0.00036333047 |
# | serial_timesteps   | 46208          |
# | time_elapsed       | 132            |
# | total_timesteps    | 46208          |
# | value_loss         | 11.947418      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0060139745 |
# | clipfrac           | 0.080078125  |
# | explained_variance | -1.55e-06    |
# | fps                | 475          |
# | n_updates          | 362          |
# | policy_entropy     | 0.79152197   |
# | policy_loss        | -0.002939652 |
# | serial_timesteps   | 46336        |
# | time_elapsed       | 133          |
# | total_timesteps    | 46336        |
# | value_loss         | 4.981502     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0053657442  |
# | clipfrac           | 0.08984375    |
# | explained_variance | 3.58e-07      |
# | fps                | 246           |
# | n_updates          | 363           |
# | policy_entropy     | 0.87354976    |
# | policy_loss        | -0.0029685714 |
# | serial_timesteps   | 46464         |
# | time_elapsed       | 133           |
# | total_timesteps    | 46464         |
# | value_loss         | 2.9402719     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0054432303 |
# | clipfrac           | 0.08203125   |
# | explained_variance | -4.89e-06    |
# | fps                | 298          |
# | n_updates          | 364          |
# | policy_entropy     | 0.7751845    |
# | policy_loss        | -0.010126296 |
# | serial_timesteps   | 46592        |
# | time_elapsed       | 133          |
# | total_timesteps    | 46592        |
# | value_loss         | 3.3916426    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0051437533  |
# | clipfrac           | 0.078125      |
# | explained_variance | -9.54e-07     |
# | fps                | 294           |
# | n_updates          | 365           |
# | policy_entropy     | 0.8034893     |
# | policy_loss        | -0.0037054005 |
# | serial_timesteps   | 46720         |
# | time_elapsed       | 134           |
# | total_timesteps    | 46720         |
# | value_loss         | 1.9638679     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.010036657   |
# | clipfrac           | 0.140625      |
# | explained_variance | -2.19e-05     |
# | fps                | 265           |
# | n_updates          | 366           |
# | policy_entropy     | 0.64960676    |
# | policy_loss        | 0.00078350515 |
# | serial_timesteps   | 46848         |
# | time_elapsed       | 134           |
# | total_timesteps    | 46848         |
# | value_loss         | 1.6924362     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0017948302 |
# | clipfrac           | 0.01171875   |
# | explained_variance | -3.58e-06    |
# | fps                | 243          |
# | n_updates          | 367          |
# | policy_entropy     | 0.81934166   |
# | policy_loss        | -0.002540169 |
# | serial_timesteps   | 46976        |
# | time_elapsed       | 135          |
# | total_timesteps    | 46976        |
# | value_loss         | 6.061156     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0040029814 |
# | clipfrac           | 0.056640625  |
# | explained_variance | 2.01e-05     |
# | fps                | 226          |
# | n_updates          | 368          |
# | policy_entropy     | 0.734613     |
# | policy_loss        | 0.0006463892 |
# | serial_timesteps   | 47104        |
# | time_elapsed       | 135          |
# | total_timesteps    | 47104        |
# | value_loss         | 5.509993     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0014604006  |
# | clipfrac           | 0.01171875    |
# | explained_variance | -0.000242     |
# | fps                | 492           |
# | n_updates          | 369           |
# | policy_entropy     | 0.8681139     |
# | policy_loss        | -0.0049265344 |
# | serial_timesteps   | 47232         |
# | time_elapsed       | 136           |
# | total_timesteps    | 47232         |
# | value_loss         | 9.305057      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.006284135  |
# | clipfrac           | 0.109375     |
# | explained_variance | -7.15e-07    |
# | fps                | 522          |
# | n_updates          | 370          |
# | policy_entropy     | 0.8654311    |
# | policy_loss        | -0.008422063 |
# | serial_timesteps   | 47360        |
# | time_elapsed       | 136          |
# | total_timesteps    | 47360        |
# | value_loss         | 2.0652492    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00023025647 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.31e-06     |
# | fps                | 385           |
# | n_updates          | 371           |
# | policy_entropy     | 0.71121156    |
# | policy_loss        | 0.00028506818 |
# | serial_timesteps   | 47488         |
# | time_elapsed       | 136           |
# | total_timesteps    | 47488         |
# | value_loss         | 2.5464945     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0002691389 |
# | clipfrac           | 0.0          |
# | explained_variance | 3.28e-06     |
# | fps                | 329          |
# | n_updates          | 372          |
# | policy_entropy     | 0.84479135   |
# | policy_loss        | 9.139482e-05 |
# | serial_timesteps   | 47616        |
# | time_elapsed       | 137          |
# | total_timesteps    | 47616        |
# | value_loss         | 7.693917     |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.00017424457  |
# | clipfrac           | 0.0            |
# | explained_variance | 2.15e-06       |
# | fps                | 280            |
# | n_updates          | 373            |
# | policy_entropy     | 0.72128356     |
# | policy_loss        | -0.00022633537 |
# | serial_timesteps   | 47744          |
# | time_elapsed       | 137            |
# | total_timesteps    | 47744          |
# | value_loss         | 4.054079       |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.004454222  |
# | clipfrac           | 0.060546875  |
# | explained_variance | 7.45e-06     |
# | fps                | 266          |
# | n_updates          | 374          |
# | policy_entropy     | 0.8476649    |
# | policy_loss        | -0.004916803 |
# | serial_timesteps   | 47872        |
# | time_elapsed       | 138          |
# | total_timesteps    | 47872        |
# | value_loss         | 1.9430802    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.003198408   |
# | clipfrac           | 0.03515625    |
# | explained_variance | 1.13e-05      |
# | fps                | 211           |
# | n_updates          | 375           |
# | policy_entropy     | 0.7425535     |
# | policy_loss        | -0.0028355515 |
# | serial_timesteps   | 48000         |
# | time_elapsed       | 138           |
# | total_timesteps    | 48000         |
# | value_loss         | 1.512635      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0025454115  |
# | clipfrac           | 0.03125       |
# | explained_variance | -4.84e-05     |
# | fps                | 233           |
# | n_updates          | 376           |
# | policy_entropy     | 0.8006037     |
# | policy_loss        | -0.0039558103 |
# | serial_timesteps   | 48128         |
# | time_elapsed       | 139           |
# | total_timesteps    | 48128         |
# | value_loss         | 10.073384     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.6624875e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 1.43e-06      |
# | fps                | 612           |
# | n_updates          | 377           |
# | policy_entropy     | 0.6367974     |
# | policy_loss        | 0.00078362634 |
# | serial_timesteps   | 48256         |
# | time_elapsed       | 139           |
# | total_timesteps    | 48256         |
# | value_loss         | 24.782618     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000194652   |
# | clipfrac           | 0.0           |
# | explained_variance | -2.38e-07     |
# | fps                | 476           |
# | n_updates          | 378           |
# | policy_entropy     | 0.8171047     |
# | policy_loss        | 0.00017958242 |
# | serial_timesteps   | 48384         |
# | time_elapsed       | 139           |
# | total_timesteps    | 48384         |
# | value_loss         | 4.286864      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0015970923 |
# | clipfrac           | 0.01171875   |
# | explained_variance | -1.91e-06    |
# | fps                | 389          |
# | n_updates          | 379          |
# | policy_entropy     | 0.8529569    |
# | policy_loss        | -0.004681709 |
# | serial_timesteps   | 48512        |
# | time_elapsed       | 140          |
# | total_timesteps    | 48512        |
# | value_loss         | 1.4312948    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.005479099   |
# | clipfrac           | 0.08203125    |
# | explained_variance | -4.53e-06     |
# | fps                | 294           |
# | n_updates          | 380           |
# | policy_entropy     | 0.8061702     |
# | policy_loss        | -0.0060984986 |
# | serial_timesteps   | 48640         |
# | time_elapsed       | 140           |
# | total_timesteps    | 48640         |
# | value_loss         | 2.9265032     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.002544465  |
# | clipfrac           | 0.04296875   |
# | explained_variance | -1.18e-05    |
# | fps                | 349          |
# | n_updates          | 381          |
# | policy_entropy     | 0.81895113   |
# | policy_loss        | -0.008190799 |
# | serial_timesteps   | 48768        |
# | time_elapsed       | 140          |
# | total_timesteps    | 48768        |
# | value_loss         | 1.9771403    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0014912714 |
# | clipfrac           | 0.0078125    |
# | explained_variance | -6.32e-06    |
# | fps                | 297          |
# | n_updates          | 382          |
# | policy_entropy     | 0.72630733   |
# | policy_loss        | 0.0011923583 |
# | serial_timesteps   | 48896        |
# | time_elapsed       | 141          |
# | total_timesteps    | 48896        |
# | value_loss         | 1.9580872    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0011974282  |
# | clipfrac           | 0.01171875    |
# | explained_variance | 0.000109      |
# | fps                | 289           |
# | n_updates          | 383           |
# | policy_entropy     | 0.7234978     |
# | policy_loss        | -0.0069806636 |
# | serial_timesteps   | 49024         |
# | time_elapsed       | 141           |
# | total_timesteps    | 49024         |
# | value_loss         | 2.3944392     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.004236188  |
# | clipfrac           | 0.0546875    |
# | explained_variance | -0.000162    |
# | fps                | 288          |
# | n_updates          | 384          |
# | policy_entropy     | 0.79503125   |
# | policy_loss        | -0.009586008 |
# | serial_timesteps   | 49152        |
# | time_elapsed       | 142          |
# | total_timesteps    | 49152        |
# | value_loss         | 6.0055957    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0022121738  |
# | clipfrac           | 0.013671875   |
# | explained_variance | 1.01e-06      |
# | fps                | 627           |
# | n_updates          | 385           |
# | policy_entropy     | 0.8806174     |
# | policy_loss        | -0.0018366989 |
# | serial_timesteps   | 49280         |
# | time_elapsed       | 142           |
# | total_timesteps    | 49280         |
# | value_loss         | 5.8470297     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.005100868   |
# | clipfrac           | 0.068359375   |
# | explained_variance | -8.34e-07     |
# | fps                | 435           |
# | n_updates          | 386           |
# | policy_entropy     | 0.7864217     |
# | policy_loss        | -0.0040775463 |
# | serial_timesteps   | 49408         |
# | time_elapsed       | 142           |
# | total_timesteps    | 49408         |
# | value_loss         | 4.193062      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0026780858 |
# | clipfrac           | 0.0390625    |
# | explained_variance | 2.38e-07     |
# | fps                | 349          |
# | n_updates          | 387          |
# | policy_entropy     | 0.8244642    |
# | policy_loss        | -0.006409709 |
# | serial_timesteps   | 49536        |
# | time_elapsed       | 143          |
# | total_timesteps    | 49536        |
# | value_loss         | 2.4283316    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0028792997  |
# | clipfrac           | 0.03515625    |
# | explained_variance | 5.6e-06       |
# | fps                | 272           |
# | n_updates          | 388           |
# | policy_entropy     | 0.6712072     |
# | policy_loss        | -0.0033298861 |
# | serial_timesteps   | 49664         |
# | time_elapsed       | 143           |
# | total_timesteps    | 49664         |
# | value_loss         | 3.1665857     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0055407574  |
# | clipfrac           | 0.0859375     |
# | explained_variance | -1.7e-05      |
# | fps                | 173           |
# | n_updates          | 389           |
# | policy_entropy     | 0.708854      |
# | policy_loss        | -0.0048809154 |
# | serial_timesteps   | 49792         |
# | time_elapsed       | 143           |
# | total_timesteps    | 49792         |
# | value_loss         | 2.3944418     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0011497041  |
# | clipfrac           | 0.00390625    |
# | explained_variance | 1.44e-05      |
# | fps                | 190           |
# | n_updates          | 390           |
# | policy_entropy     | 0.7531418     |
# | policy_loss        | -0.0004861066 |
# | serial_timesteps   | 49920         |
# | time_elapsed       | 144           |
# | total_timesteps    | 49920         |
# | value_loss         | 2.531368      |
# --------------------------------------

# %%
model.save("DQN-50000_model")

# %%
evaluate_policy(model, env,n_eval_episodes=10,render=True)
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-c7e4c687ac09> in <module>
# ----> 1 evaluate_policy(model, env,n_eval_episodes=10,render=True)
#       2 env.close()
#
# c:\Users\Aryaman\anaconda3\envs\he\lib\site-packages\stable_baselines\common\evaluation.py in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards)
#      71             episode_length += 1
#      72             if render:
# ---> 73                 env.render()
#      74         episode_rewards.append(episode_reward)
#      75         episode_lengths.append(episode_length)
#
# c:\Users\Aryaman\anaconda3\envs\he\lib\site-packages\stable_baselines\common\vec_env\dummy_vec_env.py in render(self, mode)
#      83         """
#      84         if self.num_envs == 1:
# ---> 85             return self.envs[0].render(mode=mode)
#      86         else:
#      87             return super().render(mode=mode)
#
# c:\Users\Aryaman\anaconda3\envs\he\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     252
#     253     def render(self, mode="human", **kwargs):
# --> 254         return self.env.render(mode, **kwargs)
#     255
#     256     def close(self):
#
# c:\Users\Aryaman\anaconda3\envs\he\lib\site-packages\gym\envs\box2d\lunar_lander.py in render(self, mode)
#     442             )
#     443
# --> 444         return self.viewer.render(return_rgb_array=mode == "rgb_array")
#     445
#     446     def close(self):
#
# c:\Users\Aryaman\anaconda3\envs\he\lib\site-packages\gym\envs\classic_control\rendering.py in render(self, return_rgb_array)
#     143             arr = arr.reshape(buffer.height, buffer.width, 4)
#     144             arr = arr[::-1, :, 0:3]
# --> 145         self.window.flip()
#     146         self.onetime_geoms = []
#     147         return arr if return_rgb_array else self.isopen
#
# c:\Users\Aryaman\anaconda3\envs\he\lib\site-packages\pyglet\window\win32\__init__.py in flip(self)
#     354             if self._always_dwm or self._dwm_composition_enabled():
#     355                 if self._interval:
# --> 356                     _dwmapi.DwmFlush()
#     357
#     358         self.context.flip()
#
# KeyboardInterrupt:

# %%
model = ACER.load("ACER_model", env = env)
obs = env.reset()
while True:
    env.render()
    action, _states = model.predict(obs) 
    obs, rewards, done, info = env.step(action)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-15d6531322ef> in <module>
# ----> 1 model = ACER.load("ACER_model", env = env)
#       2 obs = env.reset()
#       3 while True:
#       4     env.render()
#       5     action, _states = model.predict(obs)
#
# c:\Users\Aryaman\anaconda3\envs\he\lib\site-packages\stable_baselines\common\base_class.py in load(cls, load_path, env, custom_objects, **kwargs)
#     934         :param kwargs: extra arguments to change the model when loading
#     935         """
# --> 936         data, params = cls._load_from_file(load_path, custom_objects=custom_objects)
#     937
#     938         if 'policy_kwargs' in kwargs and kwargs['policy_kwargs'] != data['policy_kwargs']:
#
# c:\Users\Aryaman\anaconda3\envs\he\lib\site-packages\stable_baselines\common\base_class.py in _load_from_file(load_path, load_data, custom_objects)
#     649                     load_path += ".zip"
#     650                 else:
# --> 651                     raise ValueError("Error: the file {} could not be found".format(load_path))
#     652
#     653         # Open the zip archive and load data.
#
# ValueError: Error: the file ACER_model could not be found

# %%
env.close()

# %%
model = DQN.load("PPO2-100000_model", env = env)

episodes = 10
total_score =0
for episode in range(1,episodes-1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action, _states = model.predict(obs) 
        obs, reward, done, info = env.step(action)
        score+= reward
        total_score+=reward

    print('Episode:{} Score{}'.format(episode,score))
    
print("avg score", str(total_score/10))
env.close()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-59-6f4ad8c71485> in <module>
# ----> 1 model = DQN.load("PPO2-100000_model", env = env)
#       2
#       3 episodes = 10
#       4 total_score =0
#       5 for episode in range(1,episodes-1):
#
# c:\Users\Aryaman\anaconda3\envs\he\lib\site-packages\stable_baselines\common\base_class.py in load(cls, load_path, env, custom_objects, **kwargs)
#    1053         model.__dict__.update(kwargs)
#    1054         model.set_env(env)
# -> 1055         model.setup_model()
#    1056
#    1057         model.load_parameters(params)
#
# c:\Users\Aryaman\anaconda3\envs\he\lib\site-packages\stable_baselines\deepq\dqn.py in setup_model(self)
#     119             else:
#     120                 test_policy = self.policy
# --> 121             assert issubclass(test_policy, DQNPolicy), "Error: the input policy for the DQN model must be " \
#     122                                                        "an instance of DQNPolicy."
#     123
#
# AssertionError: Error: the input policy for the DQN model must be an instance of DQNPolicy.
